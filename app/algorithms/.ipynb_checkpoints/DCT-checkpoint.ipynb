# %%
from scipy.fftpack import fft, ifft, dct, idct
from scipy.ndimage import convolve1d
import np
import fourier_basis as ft
import numpy
import math
import random
import itertools
import matplotlib.pyplot as plt
import matplotlib
import time
# %matplotlib inline
import seaborn as sns
sns.set_style('white')
import basis_pursuit as bp
def flatten(nested):
    return itertools.chain(*nested)
def timeit(method):
    def timed(*args, **kw):
        ts = time.time()
        result = method(*args, **kw)
        te = time.time()
        print(method.__name__,te-ts)
        return result
    return timed
def threshold(val):
    return val if val>1 else 0
def hard_threshold(series):
    return [threshold(i) for i in series]

# %%
def sample(hz, secs, wavefreq):
    times = [i/hz for i in range(secs*hz)]
    signal = [math.exp(-t)*math.cos(2*math.pi*wavefreq*t)+0.02*(0.5-random.random()) for t in times]
    return np.Vector(*signal)
#signal = np.Vector(1,0,0,0,0).zero_mean_normalize()
signal = (sample(500, 1, 98.3)+sample(500,1,12.2)+0.5*sample(500,1,45)+0.1*sample(500,1,200.3)).zero_mean_normalize()
#3Hz wave sampled at 10Hz, one second duration
l1_spectrum = timeit(bp.sparseft)(signal)
reconstruct = bp.inverse_ft(l1_spectrum)
ff_spectrum = fft(signal)
r_fft = ifft(ff_spectrum)
#sns.tsplot(np.real(half_package(l1_ft)), color = 'b')
# Out:
# norm diff:  0.8262851169349902
# converged 0.001081228256225586
# norm diff:  4.6124336731741254e-15
# converged 0.0012843608856201172
# sparseft 1.068772792816162

# %%
sns.tsplot(signal[50:150], alpha=0.6)
sns.tsplot(reconstruct[50:150], alpha = 0.6, color = 'r')
#sns.tsplot(numpy.real(r_fft)[50:150], alpha = 0.3)
sns.despine()
# Out:
# /usr/local/lib/python3.4/dist-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
sns.tsplot(l1_spectrum[0::2])
sns.tsplot((numpy.real((ff_spectrum[1:251]))), alpha = 0.5, color = 'r')
sns.despine()
# Out:
# /usr/local/lib/python3.4/dist-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
ht_ifft = ifft(hard_threshold(ff_spectrum))
sns.tsplot(numpy.real(ht_ifft)[350:450])
sns.tsplot(signal[350:450], color = 'r')
# Out:
# /usr/local/lib/python3.4/dist-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
def c_ratio(spectrum):
    return len([i for i in spectrum if i])/len(spectrum)

# %%
c_ratio(l1_spectrum)
# Out:
# 0.03807615230460922

# %%
c_ratio(ff_spectrum)
# Out:
# 1.0

# %%
c_ratio(hard_threshold(ff_spectrum))
# Out:
# 0.024
